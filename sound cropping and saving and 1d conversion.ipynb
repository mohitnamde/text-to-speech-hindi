# %%
import matplotlib.pyplot as plt
import sounddevice as sd
import soundfile as sf
from scipy.io.wavfile import write
import os
import numpy as np

# %%
path = "C:\\main_pro\\trial_project\\HINDI\\data\\main\\"
f = "477 ज्ञृ.wav"
file = path + f
data1, sr = sf.read(file)
plo1 = data1[:]
sd.play(plo1)
plt.plot(plo1)

# %%
# # Saving 
# path = """C:\\main_pro\\trial_project\\HINDI\\data\\sound\\"""
# name = f
# print(name)
# file = path + name
# write(file, sr, plo1)  # Save as WAV file
# Out:
# 063 घौ.wav

# %%
# # 1-D conversion

# lis1 = []
# for i in range(len(data1)):
#     lis1.append(data1[i,0])
# write(file,sr,np.array(lis1))
